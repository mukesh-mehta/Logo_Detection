# %% [markdown]
# # Logo Detection on Flickr27 Logo Dataset

# %%
import csv
import random
import pandas as pd
import numpy as np
from PIL import Image, ImageOps
import cv2
from keras.utils import np_utils
import glob
# Out:
# /home/mukesh/miniconda3/envs/statoil/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Loading Dataset

# %%
txt_file = "flickr_logos_27_dataset/flickr_logos_27_dataset_training_set_annotation.txt"
test_file = "flickr_logos_27_dataset/flickr_logos_27_dataset_query_set_annotation.txt"
image_dir = "flickr_logos_27_dataset/flickr_logos_27_dataset_images/"
extra_img = "more_images/"

# %%
annot_train = np.loadtxt(txt_file, dtype='a')
annot_test = np.loadtxt(test_file, dtype='a')
new_size=(224,224)

# %%
random.seed(42)
annot_train_sample=random.sample(list(annot_train),1000)
annot_test_sample=random.sample(list(annot_train),100)

# %% [markdown]
# # Processing Images
# There is a lot of variation in size of images, all the images are resized to (224,224).
#
# ## challenges
# If the images are resized then the co-ordinates of bounding needs to be adjusted, which is done by multiplying the ratio of new size to old size.
#
# Test data has an extra class "none". So, I added some new images to training data which do not have logos from SUN 397 dataset with bounding box (0,0),(0,0).

# %%
def parse_annot(annot):
    fn = annot[0].decode('utf-8')
    class_name = annot[1].decode('utf-8')
    subset_class = annot[2].decode('utf-8')
    xmin = int(annot[3].decode('utf-8'))
    ymin = int(annot[4].decode('utf-8'))
    xmax = int(annot[5].decode('utf-8'))
    ymax = int(annot[6].decode('utf-8'))
    return fn, class_name, subset_class, xmin, ymin, xmax, ymax

def parse_test_resize(annot,new_size=new_size):
    fn = annot[0].decode('utf-8')
    class_name = annot[1].decode('utf-8')
    old_im=Image.open(image_dir+fn)
    old_size=old_im.size
    x_r = new_size[0]/old_size[0]
    y_r = new_size[1]/old_size[1]
    new_im = old_im.resize((new_size))
    return fn, new_im, class_name, x_r, y_r

def get_center_h_w(x1,y1,x2,y2):
    c_x=x1+int((x2-x1)/2)
    c_y=y1+int((y2-y1)/2)
    h=y2-y1
    w=x2-x1
    return c_x, c_y, w, h

def get_coords(c_x,c_y,w,h):
    x1 = int(c_x-(w/2))
    y1 = int(c_y-(h/2))
    x2 = int(c_x+(w/2))
    y2 = int(c_y+(h/2))
    return x1, y1, x2, y2

def process_img_resize(annot, new_size=new_size):
    fn, class_name, subset_class, xmin, ymin, xmax, ymax = parse_annot(annot)
    c_x, c_y, w, h = get_center_h_w(xmin, ymin, xmax, ymax)
    old_im=Image.open(image_dir+fn)
    old_size=old_im.size
    x_r = new_size[0]/old_size[0]
    y_r = new_size[1]/old_size[1]
    new_im = old_im.resize((new_size))
    c_x = int(c_x*x_r)
    c_y = int(c_y*y_r)
    w = int(w*x_r)
    h = int(h*y_r)
    return new_im, c_x, c_y, w, h, class_name

def new_img_to_train(images,new_size=new_size):
    img = Image.open(images)
    img = img.resize(new_size)
    class_name = 'none'
    c_x=0
    c_y=0
    h=0
    w=0
    return img,class_name, c_x, c_y, w, h

# %% [markdown]
# # Creating a Evaluation Metrics
#
# Accuracy of bounding boxes cannot be calculated directly, It is calculated by another formula "Intersection over Union (IOU)".

# %%
#Evaluation Function
def IntersectionOverUnion(box1,box2):
    xmin1,ymin1,xmax1,ymax1 = box1[0],box1[1],box1[2],box1[3]
    xmin2,ymin2,xmax2,ymax2 = box2[0],box2[1],box2[2],box2[3]
    w_I = min(xmax1,xmax2)-max(xmin1,xmin2)
    h_I = min(ymax1,ymax2)-max(ymin1,ymin2)
    if w_I <=0 or h_I <=0:
        return 0
    I=w_I *h_I
    U=(abs(xmax1-xmin1)*abs(ymax1-ymin1))+(abs(xmax2-xmin2)*abs(ymax2-ymin2))-I
    return I/U

# %%
images=[]
labels=[]
box_cx=[]
box_cy=[]
box_w=[]
box_h=[]

for annot in annot_train:
    new_im, c_x, c_y, w, h, class_name = process_img_resize(annot)
    images.append(new_im)
    labels.append(class_name)
    box_cx.append(c_x)
    box_cy.append(c_y)
    box_w.append(w)
    box_h.append(h)

for fn in glob.glob(extra_img+'/*.jpg'):
    img,class_name, c_x, c_y, w, h=new_img_to_train(fn)
    images.append(img)
    labels.append(class_name)
    box_cx.append(c_x)
    box_cy.append(c_y)
    box_w.append(w)
    box_h.append(h)

# %%
file_name=[]
test_image=[]
test_labels=[]
x_shift=[]
y_shift=[]
for annot in annot_test_sample:
    fn, new_im, class_name, x_, y_ = parse_test_resize(annot)
    file_name.append(fn)
    test_image.append(new_im)
    test_labels.append(class_name)
    x_shift.append(x_)
    y_shift.append(y_)
    
def to_csv(predictions, pred_file):
    x1=[]
    y1=[]
    x2=[]
    y2=[]
    for out in predictions/10:
        xmin, ymin, xmax, ymax=get_coords(out[0],out[1],out[2],out[3])
        x1.append(xmin)
        y1.append(ymin)
        x2.append(xmax)
        y2.append(ymax)
    test_out=pd.DataFrame(data={'file':file_name,'x1':x1,'y1':y1,'x2':x2,'y2':y2})
    test_out.to_csv("results/"+pred_file+".csv", index=False)

# %%
data=pd.DataFrame(data={'image':images,'labels':labels,'c_x':box_cx,'c_y':box_cy,'w':box_w,'h':box_h})
data.head()
# Out:
#    c_x  c_y    h                                              image  labels  \
# 0  108   82  138  <PIL.Image.Image image mode=RGB size=224x224 a...  Adidas
# 1  146  160   73  <PIL.Image.Image image mode=RGB size=224x224 a...  Adidas
# 2  109   80  138  <PIL.Image.Image image mode=RGB size=224x224 a...  Adidas
# 3  112  106  103  <PIL.Image.Image image mode=RGB size=224x224 a...  Adidas
# 4   47   34   13  <PIL.Image.Image image mode=RGB size=224x224 a...  Adidas
#
#      w
# 0  156
# 1   76
# 2  163
# 3  176
# 4   21

# %%
test_data=pd.DataFrame(data={'image':test_image,'labels':test_labels,'x_shift':x_shift,'y_shift':y_shift})
test_data.head()
# Out:
#                                                image    labels   x_shift  \
# 0  <PIL.Image.Image image mode=RGB size=224x224 a...  Cocacola  0.448000
# 1  <PIL.Image.Image image mode=RGB size=224x224 a...     Yahoo  0.448000
# 2  <PIL.Image.Image image mode=RGB size=224x224 a...     Intel  0.630986
# 3  <PIL.Image.Image image mode=RGB size=224x224 a...   Ferrari  0.448000
# 4  <PIL.Image.Image image mode=RGB size=224x224 a...  Cocacola  0.448000
#
#     y_shift
# 0  0.957265
# 1  3.500000
# 2  0.558603
# 3  0.494481
# 4  0.524590

# %%
test_image = np.array([np.array(im) for im in test_data['image']])
test_image = test_image/255

# %%
images = np.array([np.array(im) for im in data['image']])
images = images/255

# %%
box=['c_x','c_y','w','h']
boxes = data[box].values

# %%
boxes.shape
# Out:
# (4616, 4)

# %% [markdown]
# # Create Model and Train

# %%
from model import pre_trained_vgg16, pre_trained_mobilenet, vgg16_mobilenet, pre_trained_resnet50

# %%
def limit_mem():
    import keras.backend as K
    K.get_session().close()
    cfg = K.tf.ConfigProto()
    cfg.gpu_options.allow_growth = True
    K.set_session(K.tf.Session(config=cfg))
    print('gpu memory cleaned')

# %%
from sklearn.model_selection import KFold
folds=KFold(n_splits=10, random_state=42, shuffle=True)
vggpredict_te=np.zeros((len(test_image), 4))
vggpredict=np.zeros((len(images), 4))
vggIOU=0
for train,test in folds.split(images,boxes):
    limit_mem()
    X_train, X_test = images[train], images[test]
    Y_train, Y_test = boxes[train], boxes[test]
    model=None
    model=pre_trained_vgg16(images)
    hist=model.fit(X_train,Y_train, validation_data=(X_test, Y_test),epochs=2, batch_size=4,verbose=1)
    preds=model.predict(X_test,batch_size=4, verbose=1)
    vggpredict_te +=model.predict(test_image,batch_size=4, verbose=1)
    vggpredict +=model.predict(images,batch_size=4, verbose=1)
    IOU=0
    for actual,pred in zip(Y_test,preds):
        IOU+=IntersectionOverUnion(actual,pred)
    print("IOU score on validation data for this fold =",IOU/len(X_test))
    vggIOU +=IOU/len(X_test) 
    del hist, IOU
print ("IOU score for this model on validation set :", vggIOU/10)
# Out:
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 327s 79ms/step - loss: 51.5416 - val_loss: 39.0036
# Epoch 2/2
# 4154/4154 [==============================] - 315s 76ms/step - loss: 43.8798 - val_loss: 33.1248
# 462/462 [==============================] - 10s 23ms/step
# 100/100 [==============================] - 2s 22ms/step
# 4616/4616 [==============================] - 103s 22ms/step
# IOU score on validation data for this fold = 0.015026125078711013
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 319s 77ms/step - loss: 50.2331 - val_loss: 39.8109
# Epoch 2/2
# 4154/4154 [==============================] - 406s 98ms/step - loss: 42.9075 - val_loss: 37.3580
# 462/462 [==============================] - 30s 64ms/step
# 100/100 [==============================] - 7s 70ms/step
# 4616/4616 [==============================] - 149s 32ms/step
# IOU score on validation data for this fold = 0.018261072354857476
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 437s 105ms/step - loss: 48.7506 - val_loss: 36.2799
# Epoch 2/2
# 4154/4154 [==============================] - 363s 88ms/step - loss: 40.8846 - val_loss: 41.5692
# 462/462 [==============================] - 9s 20ms/step
# 100/100 [==============================] - 2s 19ms/step
# 4616/4616 [==============================] - 88s 19ms/step
# IOU score on validation data for this fold = 0.0033610064743302016
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 265s 64ms/step - loss: 47.9747 - val_loss: 42.8683
# Epoch 2/2
# 4154/4154 [==============================] - 261s 63ms/step - loss: 41.0892 - val_loss: 33.1896
# 462/462 [==============================] - 9s 20ms/step
# 100/100 [==============================] - 2s 25ms/step
# 4616/4616 [==============================] - 95s 21ms/step
# IOU score on validation data for this fold = 0.025690698134488082
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 265s 64ms/step - loss: 48.4639 - val_loss: 40.6249
# Epoch 2/2
# 4154/4154 [==============================] - 262s 63ms/step - loss: 41.7635 - val_loss: 32.9801
# 462/462 [==============================] - 9s 20ms/step
# 100/100 [==============================] - 2s 19ms/step
# 4616/4616 [==============================] - 97s 21ms/step
# IOU score on validation data for this fold = 0.02458612894856486
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 262s 63ms/step - loss: 50.2061 - val_loss: 36.0592
# Epoch 2/2
# 4154/4154 [==============================] - 262s 63ms/step - loss: 43.0313 - val_loss: 41.8087
# 462/462 [==============================] - 9s 20ms/step
# 100/100 [==============================] - 2s 25ms/step
# 4616/4616 [==============================] - 94s 20ms/step
# IOU score on validation data for this fold = 0.007535355373732943
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 263s 63ms/step - loss: 49.9376 - val_loss: 41.3799
# Epoch 2/2
# 4155/4155 [==============================] - 258s 62ms/step - loss: 43.0851 - val_loss: 32.8893
# 461/461 [==============================] - 10s 21ms/step
# 100/100 [==============================] - 2s 19ms/step
# 4616/4616 [==============================] - 96s 21ms/step
# IOU score on validation data for this fold = 0.024188029008074197
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 262s 63ms/step - loss: 46.9271 - val_loss: 37.7253
# Epoch 2/2
# 4155/4155 [==============================] - 257s 62ms/step - loss: 40.7045 - val_loss: 30.8839
# 461/461 [==============================] - 10s 21ms/step
# 100/100 [==============================] - 3s 25ms/step
# 4616/4616 [==============================] - 95s 21ms/step
# IOU score on validation data for this fold = 0.023475327930285735
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 261s 63ms/step - loss: 46.8274 - val_loss: 34.7234
# Epoch 2/2
# 4155/4155 [==============================] - 258s 62ms/step - loss: 40.8310 - val_loss: 29.8160
# 461/461 [==============================] - 10s 22ms/step
# 100/100 [==============================] - 2s 19ms/step
# 4616/4616 [==============================] - 96s 21ms/step
# IOU score on validation data for this fold = 0.031087735641631548
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 264s 64ms/step - loss: 50.3007 - val_loss: 34.5513
# Epoch 2/2
# 4155/4155 [==============================] - 257s 62ms/step - loss: 42.9236 - val_loss: 37.4962
# 461/461 [==============================] - 10s 21ms/step
# 100/100 [==============================] - 2s 25ms/step
# 4616/4616 [==============================] - 96s 21ms/step
# IOU score on validation data for this fold = 0.0060572719321320715
# IOU score for this model on validation set : 0.017926875087680812

# %%
to_csv(vggpredict_te,"vgg")

# %%
from sklearn.model_selection import KFold
folds=KFold(n_splits=10, random_state=42, shuffle=True)
mobilenetpredict_te=np.zeros((len(test_image), 4))
mobilenetpredict=np.zeros((len(images), 4))
mobilenetIOU=0
for train,test in folds.split(images,boxes):
    limit_mem()
    X_train, X_test = images[train], images[test]
    Y_train, Y_test = boxes[train], boxes[test]
    model=None
    model=pre_trained_mobilenet(images)
    hist=model.fit(X_train,Y_train, validation_data=(X_test, Y_test),epochs=2, batch_size=4,verbose=1)
    preds=model.predict(X_test,batch_size=4, verbose=1)
    mobilenetpredict_te +=model.predict(test_image,batch_size=4, verbose=1)
    mobilenetpredict +=model.predict(images,batch_size=4, verbose=1)
    IOU=0
    for actual,pred in zip(Y_test,preds):
        IOU+=IntersectionOverUnion(actual,pred)
    print("IOU score on validation data for this fold =",IOU/len(X_test))
    mobilenetIOU +=IOU/len(X_test) 
    del hist, IOU
print ("IOU score for this model on validation set :", mobilenetIOU/10)
# Out:
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 112s 27ms/step - loss: 48.7650 - val_loss: 29.0037
# Epoch 2/2
# 4154/4154 [==============================] - 98s 24ms/step - loss: 36.4040 - val_loss: 26.1456
# 462/462 [==============================] - 5s 11ms/step
# 100/100 [==============================] - 1s 8ms/step
# 4616/4616 [==============================] - 44s 9ms/step
# IOU score on validation data for this fold = 0.048169078548972566
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 118s 28ms/step - loss: 47.5961 - val_loss: 30.5324
# Epoch 2/2
# 4154/4154 [==============================] - 100s 24ms/step - loss: 36.1532 - val_loss: 24.6021
# 462/462 [==============================] - 6s 13ms/step
# 100/100 [==============================] - 1s 14ms/step
# 4616/4616 [==============================] - 44s 9ms/step
# IOU score on validation data for this fold = 0.06163646020815252
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 119s 29ms/step - loss: 51.4109 - val_loss: 28.2090
# Epoch 2/2
# 4154/4154 [==============================] - 101s 24ms/step - loss: 37.4765 - val_loss: 26.4727
# 462/462 [==============================] - 7s 14ms/step
# 100/100 [==============================] - 1s 8ms/step
# 4616/4616 [==============================] - 48s 10ms/step
# IOU score on validation data for this fold = 0.044316723703425584
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 120s 29ms/step - loss: 47.6024 - val_loss: 29.4447
# Epoch 2/2
# 4154/4154 [==============================] - 101s 24ms/step - loss: 36.6018 - val_loss: 26.5075
# 462/462 [==============================] - 7s 15ms/step
# 100/100 [==============================] - 1s 15ms/step
# 4616/4616 [==============================] - 45s 10ms/step
# IOU score on validation data for this fold = 0.0592282003919542
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 122s 29ms/step - loss: 49.2360 - val_loss: 29.4739
# Epoch 2/2
# 4154/4154 [==============================] - 100s 24ms/step - loss: 35.9228 - val_loss: 26.5173
# 462/462 [==============================] - 8s 17ms/step
# 100/100 [==============================] - 1s 8ms/step
# 4616/4616 [==============================] - 48s 10ms/step
# IOU score on validation data for this fold = 0.04541139828503529
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 123s 30ms/step - loss: 47.3189 - val_loss: 30.3869
# Epoch 2/2
# 4154/4154 [==============================] - 103s 25ms/step - loss: 36.0092 - val_loss: 26.2281
# 462/462 [==============================] - 8s 18ms/step
# 100/100 [==============================] - 1s 14ms/step
# 4616/4616 [==============================] - 46s 10ms/step
# IOU score on validation data for this fold = 0.08055930191391665
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 129s 31ms/step - loss: 47.7834 - val_loss: 30.8461
# Epoch 2/2
# 4155/4155 [==============================] - 106s 25ms/step - loss: 36.5175 - val_loss: 27.5066
# 461/461 [==============================] - 9s 20ms/step
# 100/100 [==============================] - 1s 9ms/step
# 4616/4616 [==============================] - 50s 11ms/step
# IOU score on validation data for this fold = 0.042380060988585946
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 128s 31ms/step - loss: 47.8570 - val_loss: 29.9239
# Epoch 2/2
# 4155/4155 [==============================] - 104s 25ms/step - loss: 36.4826 - val_loss: 25.0073
# 461/461 [==============================] - 10s 21ms/step
# 100/100 [==============================] - 1s 14ms/step
# 4616/4616 [==============================] - 46s 10ms/step
# IOU score on validation data for this fold = 0.05478478889046428
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 134s 32ms/step - loss: 49.8819 - val_loss: 29.6951
# Epoch 2/2
# 4155/4155 [==============================] - 107s 26ms/step - loss: 37.0169 - val_loss: 26.5015
# 461/461 [==============================] - 10s 22ms/step
# 100/100 [==============================] - 1s 9ms/step
# 4616/4616 [==============================] - 50s 11ms/step
# IOU score on validation data for this fold = 0.04021001994800555
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 133s 32ms/step - loss: 50.3980 - val_loss: 30.0289
# Epoch 2/2
# 4155/4155 [==============================] - 105s 25ms/step - loss: 36.5271 - val_loss: 25.9376
# 461/461 [==============================] - 11s 23ms/step
# 100/100 [==============================] - 1s 15ms/step
# 4616/4616 [==============================] - 47s 10ms/step
# IOU score on validation data for this fold = 0.06339159273087995
# IOU score for this model on validation set : 0.05400876256093925

# %%
to_csv(mobilenetpredict_te,"mobilenet")

# %%
from sklearn.model_selection import KFold
folds=KFold(n_splits=10, random_state=42, shuffle=True)
resnetpredict_te=np.zeros((len(test_image), 4))
resnetpredict=np.zeros((len(images), 4))
resnetIOU=0
for train,test in folds.split(images,boxes):
    limit_mem()
    X_train, X_test = images[train], images[test]
    Y_train, Y_test = boxes[train], boxes[test]
    model=None
    model=pre_trained_resnet50(images)
    hist=model.fit(X_train,Y_train, validation_data=(X_test, Y_test),epochs=2, batch_size=4,verbose=1)
    preds=model.predict(X_test,batch_size=4, verbose=1)
    resnetpredict_te +=model.predict(test_image,batch_size=4, verbose=1)
    resnetpredict +=model.predict(images,batch_size=4, verbose=1)
    IOU=0
    for actual,pred in zip(Y_test,preds):
        IOU+=IntersectionOverUnion(actual,pred)
    print("IOU score on validation data for this fold =",IOU/len(X_test))
    resnetIOU +=IOU/len(X_test) 
    del hist, IOU
print ("IOU score for this model on validation set :", resnetIOU/10)
# Out:
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 287s 69ms/step - loss: 47.0821 - val_loss: 32.9799
# Epoch 2/2
# 4154/4154 [==============================] - 246s 59ms/step - loss: 35.8313 - val_loss: 28.1439
# 462/462 [==============================] - 17s 36ms/step
# 100/100 [==============================] - 2s 19ms/step
# 4616/4616 [==============================] - 98s 21ms/step
# IOU score on validation data for this fold = 0.03939682979967132
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 293s 70ms/step - loss: 46.3752 - val_loss: 29.0342
# Epoch 2/2
# 4154/4154 [==============================] - 255s 61ms/step - loss: 36.1833 - val_loss: 25.5777
# 462/462 [==============================] - 19s 41ms/step
# 100/100 [==============================] - 3s 25ms/step
# 4616/4616 [==============================] - 97s 21ms/step
# IOU score on validation data for this fold = 0.06216115266369441
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 297s 71ms/step - loss: 48.1119 - val_loss: 35.2377
# Epoch 2/2
# 4154/4154 [==============================] - 251s 60ms/step - loss: 36.6568 - val_loss: 26.5703
# 462/462 [==============================] - 19s 42ms/step
# 100/100 [==============================] - 2s 20ms/step
# 4616/4616 [==============================] - 100s 22ms/step
# IOU score on validation data for this fold = 0.05256206301593889
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 301s 72ms/step - loss: 46.4255 - val_loss: 31.4103
# Epoch 2/2
# 4154/4154 [==============================] - 251s 60ms/step - loss: 35.8212 - val_loss: 25.6808
# 462/462 [==============================] - 21s 46ms/step
# 100/100 [==============================] - 3s 26ms/step
# 4616/4616 [==============================] - 102s 22ms/step
# IOU score on validation data for this fold = 0.07633689414985864
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 304s 73ms/step - loss: 46.2993 - val_loss: 36.0406
# Epoch 2/2
# 4154/4154 [==============================] - 252s 61ms/step - loss: 36.1658 - val_loss: 30.9810
# 462/462 [==============================] - 22s 47ms/step
# 100/100 [==============================] - 2s 20ms/step
# 4616/4616 [==============================] - 110s 24ms/step
# IOU score on validation data for this fold = 0.011130382166261022
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 308s 74ms/step - loss: 48.6290 - val_loss: 34.8463
# Epoch 2/2
# 4154/4154 [==============================] - 253s 61ms/step - loss: 36.5094 - val_loss: 28.8846
# 462/462 [==============================] - 23s 51ms/step
# 100/100 [==============================] - 3s 27ms/step
# 4616/4616 [==============================] - 123s 27ms/step
# IOU score on validation data for this fold = 0.04819669335108166
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 323s 78ms/step - loss: 47.7546 - val_loss: 32.8278
# Epoch 2/2
# 4155/4155 [==============================] - 255s 61ms/step - loss: 36.9336 - val_loss: 28.4515
# 461/461 [==============================] - 25s 53ms/step
# 100/100 [==============================] - 3s 26ms/step
# 4616/4616 [==============================] - 114s 25ms/step
# IOU score on validation data for this fold = 0.0417094176273679
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 320s 77ms/step - loss: 46.4394 - val_loss: 37.3668
# Epoch 2/2
# 4155/4155 [==============================] - 259s 62ms/step - loss: 36.2744 - val_loss: 31.0068
# 461/461 [==============================] - 27s 59ms/step
# 100/100 [==============================] - 3s 30ms/step
# 4616/4616 [==============================] - 140s 30ms/step
# IOU score on validation data for this fold = 0.057993077716303555
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 376s 90ms/step - loss: 46.8395 - val_loss: 30.7135
# Epoch 2/2
# 4155/4155 [==============================] - 312s 75ms/step - loss: 36.3327 - val_loss: 28.1181
# 461/461 [==============================] - 29s 63ms/step
# 100/100 [==============================] - 3s 31ms/step
# 4616/4616 [==============================] - 159s 34ms/step
# IOU score on validation data for this fold = 0.06250975736746378
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 381s 92ms/step - loss: 47.8629 - val_loss: 32.0733
# Epoch 2/2
# 4155/4155 [==============================] - 314s 76ms/step - loss: 36.7949 - val_loss: 28.0828
# 461/461 [==============================] - 30s 66ms/step
# 100/100 [==============================] - 4s 38ms/step
# 4616/4616 [==============================] - 151s 33ms/step
# IOU score on validation data for this fold = 0.04145656074549721
# IOU score for this model on validation set : 0.04934528286031384

# %%
to_csv(resnetpredict_te,"resnet")

# %%
from sklearn.model_selection import KFold
folds=KFold(n_splits=10, random_state=42, shuffle=True)
vm_predict_te=np.zeros((len(test_image), 4))
vm_predict=np.zeros((len(images), 4))
vm_IOU=0
for train,test in folds.split(images,boxes):
    limit_mem()
    X_train, X_test = images[train], images[test]
    Y_train, Y_test = boxes[train], boxes[test]
    model=None
    model=vgg16_mobilenet(images)
    hist=model.fit(X_train,Y_train, validation_data=(X_test, Y_test),epochs=2, batch_size=4,verbose=1)
    preds=model.predict(X_test,batch_size=4, verbose=1)
    vm_predict_te +=model.predict(test_image,batch_size=4, verbose=1)
    vm_predict +=model.predict(images,batch_size=4, verbose=1)
    IOU=0
    for actual,pred in zip(Y_test,preds):
        IOU+=IntersectionOverUnion(actual,pred)
    print("IOU score on validation data for this fold =",IOU/len(X_test))
    vm_IOU +=IOU/len(X_test) 
    del hist, IOU
print ("IOU score for this model on validation set :", vm_IOU/10)
# Out:
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 415s 100ms/step - loss: 41.3309 - val_loss: 34.7828
# Epoch 2/2
# 4154/4154 [==============================] - 353s 85ms/step - loss: 34.4203 - val_loss: 30.4406
# 462/462 [==============================] - 33s 71ms/step
# 100/100 [==============================] - 4s 45ms/step
# 4616/4616 [==============================] - 178s 39ms/step
# IOU score on validation data for this fold = 0.020964526328251947
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 420s 101ms/step - loss: 41.1543 - val_loss: 32.8700
# Epoch 2/2
# 4154/4154 [==============================] - 355s 85ms/step - loss: 34.7890 - val_loss: 29.6117
# 462/462 [==============================] - 33s 72ms/step
# 100/100 [==============================] - 4s 45ms/step
# 4616/4616 [==============================] - 177s 38ms/step
# IOU score on validation data for this fold = 0.02664182701984555
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 420s 101ms/step - loss: 42.6663 - val_loss: 32.5234
# Epoch 2/2
# 4154/4154 [==============================] - 354s 85ms/step - loss: 35.6344 - val_loss: 34.1129
# 462/462 [==============================] - 34s 73ms/step
# 100/100 [==============================] - 4s 39ms/step
# 4616/4616 [==============================] - 183s 40ms/step
# IOU score on validation data for this fold = 0.04364872291743626
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 432s 104ms/step - loss: 43.4547 - val_loss: 30.8622
# Epoch 2/2
# 4154/4154 [==============================] - 355s 85ms/step - loss: 36.5389 - val_loss: 34.9873
# 462/462 [==============================] - 34s 74ms/step
# 100/100 [==============================] - 4s 38ms/step
# 4616/4616 [==============================] - 189s 41ms/step
# IOU score on validation data for this fold = 0.010089544798950422
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 429s 103ms/step - loss: 42.6644 - val_loss: 35.7370
# Epoch 2/2
# 4154/4154 [==============================] - 363s 87ms/step - loss: 35.5280 - val_loss: 33.7827
# 462/462 [==============================] - 35s 77ms/step
# 100/100 [==============================] - 4s 38ms/step
# 4616/4616 [==============================] - 211s 46ms/step
# IOU score on validation data for this fold = 0.045892296598029104
# gpu memory cleaned
# Train on 4154 samples, validate on 462 samples
# Epoch 1/2
# 4154/4154 [==============================] - 477s 115ms/step - loss: 43.2835 - val_loss: 36.6378
# Epoch 2/2
# 4154/4154 [==============================] - 364s 88ms/step - loss: 36.4320 - val_loss: 32.4403
# 462/462 [==============================] - 36s 78ms/step
# 100/100 [==============================] - 4s 36ms/step
# 4616/4616 [==============================] - 199s 43ms/step
# IOU score on validation data for this fold = 0.045581236023583216
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 436s 105ms/step - loss: 41.4751 - val_loss: 40.6920
# Epoch 2/2
# 4155/4155 [==============================] - 366s 88ms/step - loss: 34.9350 - val_loss: 33.4426
# 461/461 [==============================] - 37s 80ms/step
# 100/100 [==============================] - 5s 48ms/step
# 4616/4616 [==============================] - 188s 41ms/step
# IOU score on validation data for this fold = 0.018718609495871084
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 437s 105ms/step - loss: 43.2345 - val_loss: 33.9995
# Epoch 2/2
# 4155/4155 [==============================] - 362s 87ms/step - loss: 35.9473 - val_loss: 30.6428
# 461/461 [==============================] - 37s 80ms/step
# 100/100 [==============================] - 5s 52ms/step
# 4616/4616 [==============================] - 202s 44ms/step
# IOU score on validation data for this fold = 0.046913816144427974
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 437s 105ms/step - loss: 41.9720 - val_loss: 31.4749
# Epoch 2/2
# 4155/4155 [==============================] - 363s 87ms/step - loss: 35.9062 - val_loss: 30.8579
# 461/461 [==============================] - 38s 82ms/step
# 100/100 [==============================] - 5s 52ms/step
# 4616/4616 [==============================] - 204s 44ms/step
# IOU score on validation data for this fold = 0.013878143606690398
# gpu memory cleaned
# Train on 4155 samples, validate on 461 samples
# Epoch 1/2
# 4155/4155 [==============================] - 441s 106ms/step - loss: 44.6598 - val_loss: 35.0139
# Epoch 2/2
# 4155/4155 [==============================] - 362s 87ms/step - loss: 36.5316 - val_loss: 31.7679
# 461/461 [==============================] - 39s 84ms/step
# 100/100 [==============================] - 5s 51ms/step
# 4616/4616 [==============================] - 196s 42ms/step
# IOU score on validation data for this fold = 0.02948435018146201
# IOU score for this model on validation set : 0.030181307311454797

# %%
to_csv(vm_predict_te,"vgg_mobile")
